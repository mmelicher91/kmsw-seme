# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. **Polynomická funkce**

# %%
def f(x):
  return (x**3) - 5* (x**2)-x 


start = 0
xend = 6
nx = 5
dx = (xend - xstart)/nx
x = np.linspace(xstart, xend, nx)
fx = f(x)

plt.plot(x, fx, "ro")

# %% [markdown]
# **Lineární aproximace**

# %%
def linear(x, a, b):
    return f(a) + (f(b)-f(a))/(b-a)*(x-a)

phi = []
xphi = []

ninterpol = 5
for i in range(len(x)-1):
    xinterpol = np.linspace(x[i], x[i+1], ninterpol) #body, které mě zajímají uvnitř interpolační funkce
    g = linear(xinterpol, x[i], x[i+1]) #hodnoty bodů interpolační funkce
    xphi.extend(xinterpol)
    phi.extend(g)

plt.plot(xphi, phi, "go-")
plt.plot(x, fx, "ro")
plt.show()

# %% [markdown]
# **Lagrange aproximace**

# %%
from scipy.interpolate import lagrange

x = np.array([1, 3, 4, 5, 6])
fx = np.array([-5, -21, -20, -5, 30])

phi = lagrange(x, fx)
print(phi)
print(phi.coef)

n = 20
xphi = np.linspace(x[0], x[-1], n)
plt.plot(xphi, phi(xphi), "go-")
plt.plot(x, fx, "ro")
plt.show()
# Out:
#           4     3     2
# 2.22e-16 x + 1 x - 5 x - 1 x
# [ 2.22044605e-16  1.00000000e+00 -5.00000000e+00 -1.00000000e+00
#   0.00000000e+00]

# %% [markdown]
# **Newtonova aproximace**

# %%
def divided_diff(x, y):    
    n = len(y)
    coef = np.zeros([n, n])
    coef[:,0] = y
    for j in range(1,n):
        for i in range(n-j):
            coef[i][j] = \
           (coef[i+1][j-1] - coef[i][j-1]) / (x[i+j]-x[i])
    return coef

def newton_poly(coef, x_data, x):
    n = len(x_data) - 1 
    p = coef[n]
    for k in range(1,n+1):
        p = coef[n-k] + (x -x_data[n-k])*p
    return p


x = np.array([1, 3, 4, 5, 6])
y = np.array([-5, -21, -20, -5, 30])

# get the divided difference coef
a_s = divided_diff(x, y)[0, :]

x_new = np.arange(x[0], x[-1], .1)
y_new = newton_poly(a_s, x, x_new)

plt.plot(x, y, 'ro')
plt.plot(x_new, y_new)

# %% [markdown]
# 2. **Harmonická funkce**

# %%
def f(x):
  return np.sin(x) 


start = 0
xend = 5
nx = 5
dx = (xend - xstart)/nx
x = np.linspace(xstart, xend, nx)
fx = f(x)

plt.plot(x, fx, "ro")

# %% [markdown]
# **Lineární aproximace**

# %%
def linear(x, a, b):
    return f(a) + (f(b)-f(a))/(b-a)*(x-a)

phi = []
xphi = []

ninterpol = 5
for i in range(len(x)-1):
    xinterpol = np.linspace(x[i], x[i+1], ninterpol) #body, které mě zajímají uvnitř interpolační funkce
    g = linear(xinterpol, x[i], x[i+1]) #hodnoty bodů interpolační funkce
    xphi.extend(xinterpol)
    phi.extend(g)

plt.plot(xphi, phi, "go-")
plt.plot(x, fx, "ro")
plt.show()

# %% [markdown]
# **Lagrange aproximace**

# %%
from scipy.interpolate import lagrange

x = np.array([0, (np.pi/2), np.pi, (np.pi*(3/2))])
fx = np.array([0, 1, 0, -1])

phi = lagrange(x, fx)
print(phi)
print(phi.coef)

n = 20
xphi = np.linspace(x[0], x[-1], n)
plt.plot(xphi, phi(xphi), "go-")
plt.plot(x, fx, "ro")
plt.show()
# Out:
#        3          2
# 0.086 x - 0.8106 x + 1.698 x
# [ 0.08600409 -0.81056947  1.69765273  0.        ]

# %% [markdown]
# **Newtonova aproximace**

# %%
def divided_diff(x, y):    
    n = len(y)
    coef = np.zeros([n, n])
    coef[:,0] = y
    for j in range(1,n):
        for i in range(n-j):
            coef[i][j] = \
           (coef[i+1][j-1] - coef[i][j-1]) / (x[i+j]-x[i])
    return coef

def newton_poly(coef, x_data, x):
    n = len(x_data) - 1 
    p = coef[n]
    for k in range(1,n+1):
        p = coef[n-k] + (x -x_data[n-k])*p
    return p


x = np.array([0, (np.pi/2), np.pi, (np.pi*(3/2))])
y = np.array([0, 1, 0, -1])

# get the divided difference coef
a_s = divided_diff(x, y)[0, :]

x_new = np.arange(x[0], x[-1], .1)
y_new = newton_poly(a_s, x, x_new)

plt.plot(x, y, 'ro')
plt.plot(x_new, y_new)

# %% [markdown]
# 3. **Exponenciální funkce**

# %%
def f(x):
  return np.exp(3/2)-np.exp(x/2)

start = 0
xend = 6
nx = 5
dx = (xend - xstart)/nx
x = np.linspace(xstart, xend, nx)
fx = f(x)

plt.plot(x, fx, "ro")

# %% [markdown]
# **Lineární aproximace**

# %%
def linear(x, a, b):
    return f(a) + (f(b)-f(a))/(b-a)*(x-a)

phi = []
xphi = []

ninterpol = 5
for i in range(len(x)-1):
    xinterpol = np.linspace(x[i], x[i+1], ninterpol) #body, které mě zajímají uvnitř interpolační funkce
    g = linear(xinterpol, x[i], x[i+1]) #hodnoty bodů interpolační funkce
    xphi.extend(xinterpol)
    phi.extend(g)

plt.plot(xphi, phi, "go-")
plt.plot(x, fx, "ro")
plt.show()

# %% [markdown]
# **Lagrange aproximace**

# %%
from scipy.interpolate import lagrange

x = np.array([0, 1, 2, 3, 4])
fx = np.array([3.48, 2.83, 1.76, 0,-2.91])

phi = lagrange(x, fx)
print(phi)
print(phi.coef)

n = 20
xphi = np.linspace(x[0], x[-1], n)
plt.plot(xphi, phi(xphi), "go-")
plt.plot(x, fx, "ro")
plt.show()
# Out:
#            4          3          2
# -0.007917 x + 0.0025 x - 0.1621 x - 0.4825 x + 3.48
# [-7.91666667e-03  2.50000000e-03 -1.62083333e-01 -4.82500000e-01
#   3.48000000e+00]

# %% [markdown]
# **Newtonova aproximace**

# %%
def divided_diff(x, y):    
    n = len(y)
    coef = np.zeros([n, n])
    coef[:,0] = y
    for j in range(1,n):
        for i in range(n-j):
            coef[i][j] = \
           (coef[i+1][j-1] - coef[i][j-1]) / (x[i+j]-x[i])
    return coef

def newton_poly(coef, x_data, x):
    n = len(x_data) - 1 
    p = coef[n]
    for k in range(1,n+1):
        p = coef[n-k] + (x -x_data[n-k])*p
    return p


x = np.array([0, 1, 2, 3, 4])
y = np.array([3.48, 2.83, 1.76, 0,-2.91])

# get the divided difference coef
a_s = divided_diff(x, y)[0, :]

x_new = np.arange(x[0], x[-1], .1)
y_new = newton_poly(a_s, x, x_new)

plt.plot(x, y, 'ro')
plt.plot(x_new, y_new)
